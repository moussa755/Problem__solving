# %%
s= "moussa"
result = []
for i in range(len(s)) :
    if s[i]==s[i].upper():
        result.append(s[i].lower())
    elif s[i]==s[i].lower():
        result.append(s[i].upper())
s = ''.join(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       5     s[i]=s[i].lower()
#       6 elif s[i]==s[i].lower():
# ----> 7     s[i]=s[i].upper()
#
# TypeError: 'str' object does not support item assignment
