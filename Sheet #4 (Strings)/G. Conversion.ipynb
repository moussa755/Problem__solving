# %%
s= 'moussa'
result = []
for i in s :
    if s[i]==s[i].upper():
        s[i]=s[i].lower()
    elif s[i]==s[i].lower():
        s[i]=s[i].upper()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 s= 'moussa'
#       2 for i in s :
# ----> 3     if s[i]==s[i].upper():
#       4         s[i]=s[i].lower()
#       5     elif s[i]==s[i].lower():
#
# TypeError: string indices must be integers, not 'str'
