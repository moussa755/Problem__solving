# %%
n=int(input())
arr=list(map(int,input().split()))
x=int(input())
# for i in range(n):
#     a=int(input())
#     arr.append(a)
if x in arr :
    print (arr.index(x))
elif x not in arr :
    print(-1)
# Out:
# -1
