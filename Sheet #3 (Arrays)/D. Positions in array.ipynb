# %%
n = int(input())
a =[]
for i in range(n):
    inp = int(input())
    a.append(inp)
print(f"A[0] = {a[0]}")
print(f"A[1] = {a[1]}")
print(f"A[3] = {a[3]}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 a =[]
#       3 for i in range(n):
# ----> 4     inp = int(input().split())
#       5     a.append(inp)
#       6 print(f"A[0] = {a[0]}")
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
A[0] = 1
A[1] = 2
A[3] = 0
5
1 2 100 0 30
